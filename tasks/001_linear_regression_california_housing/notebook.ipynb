# %% [markdown]
# # Task 001 - Linear Regression on California Housing
#
# Use this notebook for EDA and interpretation first.
#
# Before coding the model, write brief answers to:
#
# 1. What does each row represent?
# 2. What is the target and what are its units?
# 3. What does the mean baseline predict?
# 4. What should residual structure tell you about model failure?

# %%
from sklearn.datasets import fetch_california_housing

dataset = fetch_california_housing(data_home="../../data/raw/sklearn_cache", as_frame=True)
df = dataset.frame.copy()
df.head()

# %% [markdown]
# Next:
#
# - inspect shape and dtypes
# - summarize the target
# - plot the target distribution
# - inspect a few feature-target relationships
# - write down what you think Linear Regression will get wrong
